# %% [markdown]
# <h1> <center>SPACY </center></h1>
# <h1><center> Assignment 8 </center></h1>

# %% [markdown]
#  ## import libraries

# %%
# run the next line only once if needed 
# This model includes word vectors and is useful for various natural language processing tasks.
# !python -m spacy download en_core_web_lg 

# Importing the spaCy library
import spacy

# Loading the downloaded English language model for spaCy
nlp = spacy.load("en_core_web_lg")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      --------------------------------------- 1.4/587.7 MB 28.8 MB/s eta 0:00:21
#      --------------------------------------- 3.4/587.7 MB 36.1 MB/s eta 0:00:17
#      --------------------------------------- 5.5/587.7 MB 38.9 MB/s eta 0:00:15
#       -------------------------------------- 8.2/587.7 MB 43.5 MB/s eta 0:00:14
#       -------------------------------------- 9.7/587.7 MB 41.2 MB/s eta 0:00:15
#       ------------------------------------- 11.4/587.7 MB 43.5 MB/s eta 0:00:14
#       ------------------------------------- 13.5/587.7 MB 40.9 MB/s eta 0:00:15
#      - ------------------------------------ 15.5/587.7 MB 43.7 MB/s eta 0:00:14
#      - ------------------------------------ 17.9/587.7 MB 40.9 MB/s eta 0:00:14
#      - ------------------------------------ 19.9/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 22.4/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 24.8/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 26.2/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 27.2/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 28.9/587.7 MB 40.9 MB/s eta 0:00:14
#      - ------------------------------------ 30.7/587.7 MB 40.9 MB/s eta 0:00:14
#      -- ----------------------------------- 32.8/587.7 MB 38.5 MB/s eta 0:00:15
#      -- ----------------------------------- 34.0/587.7 MB 34.6 MB/s eta 0:00:17
#      -- ----------------------------------- 35.7/587.7 MB 34.4 MB/s eta 0:00:17
#      -- ----------------------------------- 37.2/587.7 MB 36.4 MB/s eta 0:00:16
#      -- ----------------------------------- 38.8/587.7 MB 36.4 MB/s eta 0:00:16
#      -- ----------------------------------- 40.8/587.7 MB 36.4 MB/s eta 0:00:16
#      -- ----------------------------------- 42.1/587.7 MB 34.4 MB/s eta 0:00:16
#      -- ----------------------------------- 43.4/587.7 MB 29.7 MB/s eta 0:00:19
#      -- ----------------------------------- 45.8/587.7 MB 29.7 MB/s eta 0:00:19
#      --- ---------------------------------- 46.7/587.7 MB 28.5 MB/s eta 0:00:19
#      --- ---------------------------------- 48.5/587.7 MB 27.3 MB/s eta 0:00:20
#      --- ---------------------------------- 50.3/587.7 MB 27.3 MB/s eta 0:00:20
#      --- ---------------------------------- 52.3/587.7 MB 28.5 MB/s eta 0:00:19
#      --- ---------------------------------- 53.7/587.7 MB 32.8 MB/s eta 0:00:17
#      --- ---------------------------------- 55.7/587.7 MB 32.7 MB/s eta 0:00:17
#      --- ---------------------------------- 58.1/587.7 MB 38.5 MB/s eta 0:00:14
#      --- ---------------------------------- 59.9/587.7 MB 40.9 MB/s eta 0:00:13
#      ---- --------------------------------- 61.9/587.7 MB 43.5 MB/s eta 0:00:13
#      ---- --------------------------------- 64.1/587.7 MB 46.9 MB/s eta 0:00:12
#      ---- --------------------------------- 66.2/587.7 MB 46.9 MB/s eta 0:00:12
#      ---- --------------------------------- 68.0/587.7 MB 43.7 MB/s eta 0:00:12
#      ---- --------------------------------- 69.2/587.7 MB 38.5 MB/s eta 0:00:14
#      ---- --------------------------------- 70.6/587.7 MB 34.4 MB/s eta 0:00:16
#      ---- --------------------------------- 73.0/587.7 MB 34.4 MB/s eta 0:00:15
#      ---- --------------------------------- 75.7/587.7 MB 36.4 MB/s eta 0:00:15
#      ----- -------------------------------- 77.9/587.7 MB 36.4 MB/s eta 0:00:15
#      ----- -------------------------------- 80.5/587.7 MB 50.4 MB/s eta 0:00:11
#      ----- -------------------------------- 81.2/587.7 MB 54.7 MB/s eta 0:00:10
#      ----- -------------------------------- 83.6/587.7 MB 46.9 MB/s eta 0:00:11
#      ----- -------------------------------- 85.0/587.7 MB 40.9 MB/s eta 0:00:13
#      ----- -------------------------------- 86.0/587.7 MB 38.5 MB/s eta 0:00:14
#      ----- -------------------------------- 87.2/587.7 MB 32.7 MB/s eta 0:00:16
#      ----- -------------------------------- 88.9/587.7 MB 31.1 MB/s eta 0:00:17
#      ----- -------------------------------- 91.1/587.7 MB 29.7 MB/s eta 0:00:17
#      ----- -------------------------------- 92.5/587.7 MB 29.7 MB/s eta 0:00:17
#      ------ ------------------------------- 94.5/587.7 MB 26.2 MB/s eta 0:00:19
#      ------ ------------------------------- 95.9/587.7 MB 25.2 MB/s eta 0:00:20
#      ------ ------------------------------- 97.9/587.7 MB 27.3 MB/s eta 0:00:18
#      ------ ------------------------------- 99.5/587.7 MB 27.3 MB/s eta 0:00:18
#      ------ ------------------------------ 100.6/587.7 MB 25.2 MB/s eta 0:00:20
#      ------ ------------------------------ 102.7/587.7 MB 28.5 MB/s eta 0:00:18
#      ------ ------------------------------ 107.0/587.7 MB 46.7 MB/s eta 0:00:11
#      ------ ------------------------------ 109.4/587.7 MB 50.4 MB/s eta 0:00:10
#      ------ ------------------------------ 110.8/587.7 MB 54.4 MB/s eta 0:00:09
#      ------- ----------------------------- 111.8/587.7 MB 46.7 MB/s eta 0:00:11
#      ------- ----------------------------- 113.4/587.7 MB 40.9 MB/s eta 0:00:12
#      ------- ----------------------------- 114.6/587.7 MB 34.6 MB/s eta 0:00:14
#      ------- ----------------------------- 116.1/587.7 MB 29.7 MB/s eta 0:00:16
#      ------- ----------------------------- 118.3/587.7 MB 27.3 MB/s eta 0:00:18
#      ------- ----------------------------- 120.3/587.7 MB 27.3 MB/s eta 0:00:18
#      ------- ----------------------------- 122.6/587.7 MB 34.4 MB/s eta 0:00:14
#      ------- ----------------------------- 125.0/587.7 MB 43.7 MB/s eta 0:00:11
#      -------- ---------------------------- 127.9/587.7 MB 54.7 MB/s eta 0:00:09
#      -------- ---------------------------- 130.2/587.7 MB 54.7 MB/s eta 0:00:09
#      -------- ---------------------------- 131.2/587.7 MB 46.7 MB/s eta 0:00:10
#      -------- ---------------------------- 133.0/587.7 MB 43.5 MB/s eta 0:00:11
#      -------- ---------------------------- 134.9/587.7 MB 40.9 MB/s eta 0:00:12
#      -------- ---------------------------- 136.7/587.7 MB 38.6 MB/s eta 0:00:12
#      -------- ---------------------------- 138.6/587.7 MB 34.4 MB/s eta 0:00:14
#      -------- ---------------------------- 140.9/587.7 MB 36.3 MB/s eta 0:00:13
#      --------- --------------------------- 143.3/587.7 MB 43.5 MB/s eta 0:00:11
#      --------- --------------------------- 145.1/587.7 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 147.0/587.7 MB 43.7 MB/s eta 0:00:11
#      --------- --------------------------- 148.8/587.7 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 151.2/587.7 MB 43.7 MB/s eta 0:00:10
#      --------- --------------------------- 153.2/587.7 MB 43.7 MB/s eta 0:00:10
#      --------- --------------------------- 154.9/587.7 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 156.2/587.7 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 157.7/587.7 MB 36.4 MB/s eta 0:00:12
#      ---------- -------------------------- 160.5/587.7 MB 36.3 MB/s eta 0:00:12
#      ---------- -------------------------- 162.4/587.7 MB 32.8 MB/s eta 0:00:13
#      ---------- -------------------------- 164.5/587.7 MB 34.4 MB/s eta 0:00:13
#      ---------- -------------------------- 166.7/587.7 MB 34.4 MB/s eta 0:00:13
#      ---------- -------------------------- 167.5/587.7 MB 31.2 MB/s eta 0:00:14
#      ---------- -------------------------- 169.9/587.7 MB 32.7 MB/s eta 0:00:13
#      ---------- -------------------------- 172.0/587.7 MB 34.6 MB/s eta 0:00:13
#      ---------- -------------------------- 174.1/587.7 MB 34.4 MB/s eta 0:00:13
#      ----------- ------------------------- 175.0/587.7 MB 31.2 MB/s eta 0:00:14
#      ----------- ------------------------- 176.0/587.7 MB 26.2 MB/s eta 0:00:16
#      ----------- ------------------------- 177.5/587.7 MB 25.1 MB/s eta 0:00:17
#      ----------- ------------------------- 178.8/587.7 MB 24.2 MB/s eta 0:00:17
#      ----------- ------------------------- 180.9/587.7 MB 23.4 MB/s eta 0:00:18
#      ----------- ------------------------- 183.0/587.7 MB 23.4 MB/s eta 0:00:18
#      ----------- ------------------------- 184.8/587.7 MB 23.4 MB/s eta 0:00:18
#      ----------- ------------------------- 185.9/587.7 MB 27.3 MB/s eta 0:00:15
#      ----------- ------------------------- 186.6/587.7 MB 29.7 MB/s eta 0:00:14
#      ----------- ------------------------- 188.2/587.7 MB 31.2 MB/s eta 0:00:13
#      ----------- ------------------------- 189.2/587.7 MB 28.5 MB/s eta 0:00:14
#      ------------ ------------------------ 191.2/587.7 MB 26.2 MB/s eta 0:00:16
#      ------------ ------------------------ 193.2/587.7 MB 25.2 MB/s eta 0:00:16
#      ------------ ------------------------ 195.4/587.7 MB 25.2 MB/s eta 0:00:16
#      ------------ ------------------------ 197.0/587.7 MB 28.5 MB/s eta 0:00:14
#      ------------ ------------------------ 198.7/587.7 MB 27.3 MB/s eta 0:00:15
#      ------------ ------------------------ 201.5/587.7 MB 36.3 MB/s eta 0:00:11
#      ------------ ------------------------ 205.1/587.7 MB 50.4 MB/s eta 0:00:08
#      ------------- ----------------------- 207.4/587.7 MB 54.4 MB/s eta 0:00:07
#      ------------- ----------------------- 209.2/587.7 MB 54.7 MB/s eta 0:00:07
#      ------------- ----------------------- 211.1/587.7 MB 38.5 MB/s eta 0:00:10
#      ------------- ----------------------- 213.3/587.7 MB 32.7 MB/s eta 0:00:12
#      ------------- ----------------------- 215.6/587.7 MB 28.4 MB/s eta 0:00:14
#      ------------- ----------------------- 217.2/587.7 MB 26.2 MB/s eta 0:00:15
#      ------------- ----------------------- 219.0/587.7 MB 24.2 MB/s eta 0:00:16
#      ------------- ----------------------- 222.1/587.7 MB 32.7 MB/s eta 0:00:12
#      -------------- ---------------------- 224.0/587.7 MB 34.4 MB/s eta 0:00:11
#      -------------- ---------------------- 225.9/587.7 MB 38.5 MB/s eta 0:00:10
#      -------------- ---------------------- 227.6/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 229.6/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 231.0/587.7 MB 32.7 MB/s eta 0:00:11
#      -------------- ---------------------- 232.3/587.7 MB 27.3 MB/s eta 0:00:14
#      -------------- ---------------------- 233.3/587.7 MB 25.2 MB/s eta 0:00:15
#      -------------- ---------------------- 235.0/587.7 MB 21.8 MB/s eta 0:00:17
#      -------------- ---------------------- 237.1/587.7 MB 22.6 MB/s eta 0:00:16
#      --------------- --------------------- 238.8/587.7 MB 22.6 MB/s eta 0:00:16
#      --------------- --------------------- 239.6/587.7 MB 21.1 MB/s eta 0:00:17
#      --------------- --------------------- 240.9/587.7 MB 21.8 MB/s eta 0:00:16
#      --------------- --------------------- 242.4/587.7 MB 23.4 MB/s eta 0:00:15
#      --------------- --------------------- 244.4/587.7 MB 29.7 MB/s eta 0:00:12
#      --------------- --------------------- 245.5/587.7 MB 26.2 MB/s eta 0:00:14
#      --------------- --------------------- 246.8/587.7 MB 25.2 MB/s eta 0:00:14
#      --------------- --------------------- 247.9/587.7 MB 24.2 MB/s eta 0:00:15
#      --------------- --------------------- 249.5/587.7 MB 24.2 MB/s eta 0:00:14
#      --------------- --------------------- 251.3/587.7 MB 27.3 MB/s eta 0:00:13
#      --------------- --------------------- 253.4/587.7 MB 31.1 MB/s eta 0:00:11
#      ---------------- -------------------- 255.0/587.7 MB 32.8 MB/s eta 0:00:11
#      ---------------- -------------------- 257.1/587.7 MB 38.6 MB/s eta 0:00:09
#      ---------------- -------------------- 259.7/587.7 MB 40.9 MB/s eta 0:00:09
#      ---------------- -------------------- 259.9/587.7 MB 40.9 MB/s eta 0:00:09
#      ---------------- -------------------- 260.4/587.7 MB 31.2 MB/s eta 0:00:11
#      ---------------- -------------------- 261.4/587.7 MB 25.2 MB/s eta 0:00:13
#      ---------------- -------------------- 262.1/587.7 MB 24.2 MB/s eta 0:00:14
#      ---------------- -------------------- 262.3/587.7 MB 21.1 MB/s eta 0:00:16
#      ---------------- -------------------- 263.5/587.7 MB 18.7 MB/s eta 0:00:18
#      ---------------- -------------------- 263.9/587.7 MB 19.3 MB/s eta 0:00:17
#      ---------------- -------------------- 264.4/587.7 MB 16.8 MB/s eta 0:00:20
#      ---------------- -------------------- 265.7/587.7 MB 16.4 MB/s eta 0:00:20
#      ---------------- -------------------- 267.1/587.7 MB 16.0 MB/s eta 0:00:21
#      ---------------- -------------------- 268.3/587.7 MB 16.0 MB/s eta 0:00:21
#      ---------------- -------------------- 269.1/587.7 MB 14.9 MB/s eta 0:00:22
#      ----------------- ------------------- 270.7/587.7 MB 16.4 MB/s eta 0:00:20
#      ----------------- ------------------- 271.9/587.7 MB 17.3 MB/s eta 0:00:19
#      ----------------- ------------------- 273.6/587.7 MB 21.1 MB/s eta 0:00:15
#      ----------------- ------------------- 276.6/587.7 MB 29.7 MB/s eta 0:00:11
#      ----------------- ------------------- 279.1/587.7 MB 36.4 MB/s eta 0:00:09
#      ----------------- ------------------- 282.0/587.7 MB 54.4 MB/s eta 0:00:06
#      ----------------- ------------------- 284.1/587.7 MB 59.5 MB/s eta 0:00:06
#      ----------------- ------------------- 285.7/587.7 MB 50.1 MB/s eta 0:00:07
#      ------------------ ------------------ 287.0/587.7 MB 46.9 MB/s eta 0:00:07
#      ------------------ ------------------ 288.8/587.7 MB 40.9 MB/s eta 0:00:08
#      ------------------ ------------------ 291.1/587.7 MB 38.5 MB/s eta 0:00:08
#      ------------------ ------------------ 292.2/587.7 MB 32.8 MB/s eta 0:00:10
#      ------------------ ------------------ 293.4/587.7 MB 31.2 MB/s eta 0:00:10
#      ------------------ ------------------ 295.2/587.7 MB 29.7 MB/s eta 0:00:10
#      ------------------ ------------------ 298.7/587.7 MB 36.4 MB/s eta 0:00:08
#      ------------------ ------------------ 301.3/587.7 MB 36.4 MB/s eta 0:00:08
#      ------------------- ----------------- 302.7/587.7 MB 40.9 MB/s eta 0:00:07
#      ------------------- ----------------- 304.8/587.7 MB 46.7 MB/s eta 0:00:07
#      ------------------- ----------------- 306.0/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------- ----------------- 310.4/587.7 MB 46.7 MB/s eta 0:00:06
#      ------------------- ----------------- 312.8/587.7 MB 50.4 MB/s eta 0:00:06
#      ------------------- ----------------- 313.8/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------- ----------------- 315.4/587.7 MB 43.5 MB/s eta 0:00:07
#      -------------------- ---------------- 317.7/587.7 MB 43.7 MB/s eta 0:00:07
#      -------------------- ---------------- 319.4/587.7 MB 36.4 MB/s eta 0:00:08
#      -------------------- ---------------- 321.3/587.7 MB 31.2 MB/s eta 0:00:09
#      -------------------- ---------------- 322.9/587.7 MB 29.7 MB/s eta 0:00:09
#      -------------------- ---------------- 324.8/587.7 MB 29.8 MB/s eta 0:00:09
#      -------------------- ---------------- 326.5/587.7 MB 31.2 MB/s eta 0:00:09
#      -------------------- ---------------- 329.4/587.7 MB 36.4 MB/s eta 0:00:08
#      -------------------- ---------------- 330.5/587.7 MB 34.4 MB/s eta 0:00:08
#      -------------------- ---------------- 331.4/587.7 MB 31.2 MB/s eta 0:00:09
#      --------------------- --------------- 334.2/587.7 MB 34.4 MB/s eta 0:00:08
#      --------------------- --------------- 335.7/587.7 MB 28.5 MB/s eta 0:00:09
#      --------------------- --------------- 337.5/587.7 MB 29.7 MB/s eta 0:00:09
#      --------------------- --------------- 340.3/587.7 MB 27.3 MB/s eta 0:00:10
#      --------------------- --------------- 342.3/587.7 MB 31.2 MB/s eta 0:00:08
#      --------------------- --------------- 344.7/587.7 MB 34.4 MB/s eta 0:00:08
#      --------------------- --------------- 347.1/587.7 MB 43.7 MB/s eta 0:00:06
#      ---------------------- -------------- 350.0/587.7 MB 50.4 MB/s eta 0:00:05
#      ---------------------- -------------- 353.4/587.7 MB 65.2 MB/s eta 0:00:04
#      ---------------------- -------------- 356.0/587.7 MB 65.2 MB/s eta 0:00:04
#      ---------------------- -------------- 358.9/587.7 MB 65.6 MB/s eta 0:00:04
#      ---------------------- -------------- 361.2/587.7 MB 50.1 MB/s eta 0:00:05
#      ---------------------- -------------- 363.2/587.7 MB 40.9 MB/s eta 0:00:06
#      ---------------------- -------------- 364.9/587.7 MB 34.4 MB/s eta 0:00:07
#      ----------------------- ------------- 366.1/587.7 MB 31.2 MB/s eta 0:00:08
#      ----------------------- ------------- 368.6/587.7 MB 31.1 MB/s eta 0:00:08
#      ----------------------- ------------- 371.3/587.7 MB 34.6 MB/s eta 0:00:07
#      ----------------------- ------------- 374.8/587.7 MB 50.4 MB/s eta 0:00:05
#      ----------------------- ------------- 377.9/587.7 MB 65.6 MB/s eta 0:00:04
#      ----------------------- ------------- 379.8/587.7 MB 59.5 MB/s eta 0:00:04
#      ----------------------- ------------- 380.9/587.7 MB 50.4 MB/s eta 0:00:05
#      ------------------------ ------------ 382.3/587.7 MB 46.7 MB/s eta 0:00:05
#      ------------------------ ------------ 383.1/587.7 MB 36.4 MB/s eta 0:00:06
#      ------------------------ ------------ 383.4/587.7 MB 31.2 MB/s eta 0:00:07
#      ------------------------ ------------ 384.0/587.7 MB 27.3 MB/s eta 0:00:08
#      ------------------------ ------------ 384.5/587.7 MB 23.4 MB/s eta 0:00:09
#      ------------------------ ------------ 385.2/587.7 MB 21.1 MB/s eta 0:00:10
#      ------------------------ ------------ 387.8/587.7 MB 20.5 MB/s eta 0:00:10
#      ------------------------ ------------ 390.6/587.7 MB 21.9 MB/s eta 0:00:10
#      ------------------------ ------------ 393.8/587.7 MB 36.3 MB/s eta 0:00:06
#      ------------------------ ------------ 396.6/587.7 MB 65.2 MB/s eta 0:00:03
#      ------------------------- ----------- 399.2/587.7 MB 65.6 MB/s eta 0:00:03
#      ------------------------- ----------- 400.3/587.7 MB 54.7 MB/s eta 0:00:04
#      ------------------------- ----------- 401.0/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------- ----------- 401.9/587.7 MB 34.4 MB/s eta 0:00:06
#      ------------------------- ----------- 402.6/587.7 MB 29.7 MB/s eta 0:00:07
#      ------------------------- ----------- 403.3/587.7 MB 25.2 MB/s eta 0:00:08
#      ------------------------- ----------- 403.9/587.7 MB 21.9 MB/s eta 0:00:09
#      ------------------------- ----------- 404.4/587.7 MB 20.5 MB/s eta 0:00:09
#      ------------------------- ----------- 406.7/587.7 MB 19.9 MB/s eta 0:00:10
#      ------------------------- ----------- 409.9/587.7 MB 21.1 MB/s eta 0:00:09
#      ------------------------- ----------- 412.9/587.7 MB 32.7 MB/s eta 0:00:06
#      -------------------------- ---------- 415.6/587.7 MB 65.6 MB/s eta 0:00:03
#      -------------------------- ---------- 418.1/587.7 MB 59.5 MB/s eta 0:00:03
#      -------------------------- ---------- 419.8/587.7 MB 46.7 MB/s eta 0:00:04
#      -------------------------- ---------- 421.6/587.7 MB 40.9 MB/s eta 0:00:05
#      -------------------------- ---------- 423.6/587.7 MB 36.4 MB/s eta 0:00:05
#      -------------------------- ---------- 425.5/587.7 MB 32.8 MB/s eta 0:00:05
#      -------------------------- ---------- 426.7/587.7 MB 29.7 MB/s eta 0:00:06
#      -------------------------- ---------- 428.1/587.7 MB 25.2 MB/s eta 0:00:07
#      --------------------------- --------- 430.1/587.7 MB 27.3 MB/s eta 0:00:06
#      --------------------------- --------- 432.7/587.7 MB 29.8 MB/s eta 0:00:06
#      --------------------------- --------- 435.2/587.7 MB 32.8 MB/s eta 0:00:05
#      --------------------------- --------- 436.9/587.7 MB 43.7 MB/s eta 0:00:04
#      --------------------------- --------- 438.8/587.7 MB 43.7 MB/s eta 0:00:04
#      --------------------------- --------- 440.5/587.7 MB 43.5 MB/s eta 0:00:04
#      --------------------------- --------- 442.7/587.7 MB 38.6 MB/s eta 0:00:04
#      --------------------------- --------- 444.4/587.7 MB 38.6 MB/s eta 0:00:04
#      ---------------------------- -------- 446.5/587.7 MB 38.5 MB/s eta 0:00:04
#      ---------------------------- -------- 447.4/587.7 MB 34.4 MB/s eta 0:00:05
#      ---------------------------- -------- 449.3/587.7 MB 34.4 MB/s eta 0:00:05
#      ---------------------------- -------- 449.5/587.7 MB 34.6 MB/s eta 0:00:04
#      ---------------------------- -------- 449.5/587.7 MB 34.6 MB/s eta 0:00:04
#      ---------------------------- -------- 449.6/587.7 MB 25.2 MB/s eta 0:00:06
#      ---------------------------- -------- 450.7/587.7 MB 23.4 MB/s eta 0:00:06
#      ---------------------------- -------- 452.1/587.7 MB 22.6 MB/s eta 0:00:07
#      ---------------------------- -------- 452.9/587.7 MB 21.8 MB/s eta 0:00:07
#      ---------------------------- -------- 453.6/587.7 MB 20.5 MB/s eta 0:00:07
#      ---------------------------- -------- 454.4/587.7 MB 18.7 MB/s eta 0:00:08
#      ---------------------------- -------- 455.0/587.7 MB 18.2 MB/s eta 0:00:08
#      ---------------------------- -------- 455.6/587.7 MB 17.2 MB/s eta 0:00:08
#      ---------------------------- -------- 456.3/587.7 MB 16.4 MB/s eta 0:00:09
#      ---------------------------- -------- 457.2/587.7 MB 16.4 MB/s eta 0:00:08
#      ---------------------------- -------- 458.1/587.7 MB 15.2 MB/s eta 0:00:09
#      ---------------------------- -------- 459.5/587.7 MB 15.2 MB/s eta 0:00:09
#      ---------------------------- -------- 460.3/587.7 MB 17.3 MB/s eta 0:00:08
#      ----------------------------- ------- 461.6/587.7 MB 17.3 MB/s eta 0:00:08
#      ----------------------------- ------- 462.8/587.7 MB 17.2 MB/s eta 0:00:08
#      ----------------------------- ------- 464.0/587.7 MB 18.2 MB/s eta 0:00:07
#      ----------------------------- ------- 465.1/587.7 MB 19.8 MB/s eta 0:00:07
#      ----------------------------- ------- 466.2/587.7 MB 21.1 MB/s eta 0:00:06
#      ----------------------------- ------- 467.2/587.7 MB 21.1 MB/s eta 0:00:06
#      ----------------------------- ------- 468.0/587.7 MB 20.5 MB/s eta 0:00:06
#      ----------------------------- ------- 468.6/587.7 MB 20.5 MB/s eta 0:00:06
#      ----------------------------- ------- 470.5/587.7 MB 23.4 MB/s eta 0:00:06
#      ----------------------------- ------- 473.3/587.7 MB 27.3 MB/s eta 0:00:05
#      ----------------------------- ------- 475.6/587.7 MB 31.2 MB/s eta 0:00:04
#      ------------------------------ ------ 477.8/587.7 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 479.7/587.7 MB 50.4 MB/s eta 0:00:03
#      ------------------------------ ------ 482.3/587.7 MB 43.5 MB/s eta 0:00:03
#      ------------------------------ ------ 483.9/587.7 MB 36.4 MB/s eta 0:00:03
#      ------------------------------ ------ 486.5/587.7 MB 36.3 MB/s eta 0:00:03
#      ------------------------------ ------ 487.9/587.7 MB 32.8 MB/s eta 0:00:04
#      ------------------------------ ------ 489.8/587.7 MB 29.7 MB/s eta 0:00:04
#      ------------------------------ ------ 491.2/587.7 MB 29.7 MB/s eta 0:00:04
#      ------------------------------- ----- 493.5/587.7 MB 34.4 MB/s eta 0:00:03
#      ------------------------------- ----- 495.2/587.7 MB 32.7 MB/s eta 0:00:03
#      ------------------------------- ----- 497.1/587.7 MB 36.3 MB/s eta 0:00:03
#      ------------------------------- ----- 499.9/587.7 MB 43.5 MB/s eta 0:00:03
#      ------------------------------- ----- 502.3/587.7 MB 46.9 MB/s eta 0:00:02
#      ------------------------------- ----- 503.5/587.7 MB 40.9 MB/s eta 0:00:03
#      ------------------------------- ----- 504.5/587.7 MB 34.6 MB/s eta 0:00:03
#      ------------------------------- ----- 506.2/587.7 MB 36.4 MB/s eta 0:00:03
#      ------------------------------- ----- 507.4/587.7 MB 31.2 MB/s eta 0:00:03
#      -------------------------------- ---- 510.2/587.7 MB 29.8 MB/s eta 0:00:03
#      -------------------------------- ---- 512.8/587.7 MB 32.8 MB/s eta 0:00:03
#      -------------------------------- ---- 516.1/587.7 MB 46.7 MB/s eta 0:00:02
#      -------------------------------- ---- 519.2/587.7 MB 65.6 MB/s eta 0:00:02
#      -------------------------------- ---- 522.5/587.7 MB 65.6 MB/s eta 0:00:01
#      --------------------------------- --- 525.2/587.7 MB 65.2 MB/s eta 0:00:01
#      --------------------------------- --- 526.7/587.7 MB 59.5 MB/s eta 0:00:02
#      --------------------------------- --- 528.0/587.7 MB 46.7 MB/s eta 0:00:02
#      --------------------------------- --- 528.8/587.7 MB 38.5 MB/s eta 0:00:02
#      --------------------------------- --- 529.4/587.7 MB 34.4 MB/s eta 0:00:02
#      --------------------------------- --- 530.7/587.7 MB 29.8 MB/s eta 0:00:02
#      --------------------------------- --- 532.6/587.7 MB 28.5 MB/s eta 0:00:02
#      --------------------------------- --- 534.8/587.7 MB 27.3 MB/s eta 0:00:02
#      --------------------------------- --- 536.7/587.7 MB 27.3 MB/s eta 0:00:02
#      --------------------------------- --- 538.7/587.7 MB 32.7 MB/s eta 0:00:02
#      ---------------------------------- -- 540.4/587.7 MB 40.9 MB/s eta 0:00:02
#      ---------------------------------- -- 541.9/587.7 MB 38.5 MB/s eta 0:00:02
#      ---------------------------------- -- 545.9/587.7 MB 46.9 MB/s eta 0:00:01
#      ---------------------------------- -- 549.3/587.7 MB 54.7 MB/s eta 0:00:01
#      ---------------------------------- -- 551.4/587.7 MB 65.6 MB/s eta 0:00:01
#      ---------------------------------- -- 553.0/587.7 MB 54.4 MB/s eta 0:00:01
#      ---------------------------------- -- 553.9/587.7 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 556.7/587.7 MB 32.7 MB/s eta 0:00:01
#      ----------------------------------- - 558.4/587.7 MB 29.8 MB/s eta 0:00:01
#      ----------------------------------- - 559.9/587.7 MB 26.2 MB/s eta 0:00:02
#      ----------------------------------- - 561.6/587.7 MB 26.2 MB/s eta 0:00:01
#      ----------------------------------- - 564.4/587.7 MB 31.2 MB/s eta 0:00:01
#      ----------------------------------- - 568.6/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  572.5/587.7 MB 72.6 MB/s eta 0:00:01
#      ------------------------------------  574.9/587.7 MB 72.6 MB/s eta 0:00:01
#      ------------------------------------  576.6/587.7 MB 54.7 MB/s eta 0:00:01
#      ------------------------------------  578.0/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  579.2/587.7 MB 38.5 MB/s eta 0:00:01
#      ------------------------------------  580.8/587.7 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  583.4/587.7 MB 31.2 MB/s eta 0:00:01
#      ------------------------------------  586.1/587.7 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 38.6 MB/s eta 0:00:01
#      -------------------------------------- 587.7/587.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %% [markdown]
#  ## Tokenization on text

# %%
# Define a text string containing a sentence.
text = "I am fond of Paulo Coelho novels , The Alchemist is one of my favourite "

# Process the text using the spaCy language model loaded previously.
doc = nlp(text)

# Iterate through each token in the processed document and print them with a delimiter "|".
for token in doc:
    print(token, end=' | ')
# Out:
# I | am | fond | of | Paulo | Coelho | novels | , | The | Alchemist | is | one | of | my | favourite |

# %% [markdown]
#  ## The attributes the Spacy adds

# %%
# Import the pandas library with alias pd for data manipulation and analysis.
import pandas as pd

# Define a function display_nlp that takes a spaCy document (doc) and an optional flag (include_punct) 
# to decide whether to include punctuation tokens in the output DataFrame.
def display_nlp(doc, include_punct=False):
    """
    Generate a DataFrame for visualization of spaCy tokens.
    
    Parameters:
        doc (spacy.Doc): The processed spaCy document.
        include_punct (bool): Flag to include punctuation tokens. Default is False.

    Returns:
        pd.DataFrame: DataFrame containing token information.
    """
    # Initialize an empty list to store rows of token information.
    rows = []
    
    # Iterate through each token in the spaCy document.
    for i, t in enumerate(doc):
        # Check if the token is not punctuation or if include_punct flag is True.
        if not t.is_punct or include_punct:
            # Create a dictionary containing token information.
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            # Append the dictionary to the rows list.
            rows.append(row)
    
    # Create a DataFrame from the list of token information rows.
    df = pd.DataFrame(rows).set_index('token')
    
    # Set the index name to None for cleaner display.
    df.index.name = None
    
    # Return the DataFrame.
    return df

# Call the display_nlp function with the spaCy document (doc) to generate a DataFrame
# for visualization of spaCy tokens.
display_nlp(doc)
# Out:
#          text     lemma_  is_stop  is_alpha   pos_      dep_ ent_type_  \
# 0           I          I     True      True   PRON     nsubj
# 1          am         be     True      True    AUX     ccomp
# 2        fond       fond    False      True    ADJ     acomp
# 3          of         of     True      True    ADP      prep
# 4       Paulo      Paulo    False      True  PROPN  compound    PERSON
# 5      Coelho     Coelho    False      True  PROPN  compound    PERSON
# 6      novels      novel    False      True   NOUN      pobj
# 8         The        the     True      True    DET       det
# 9   Alchemist  Alchemist    False      True  PROPN     nsubj       ORG
# 10         is         be     True      True    AUX      ROOT
# 11        one        one     True      True    NUM      attr
# 12         of         of     True      True    ADP      prep
# 13         my         my     True      True   PRON      poss
# 14  favourite  favourite    False      True    ADJ      pobj
#
#    ent_iob_
# 0         O
# 1         O
# 2         O
# 3         O
# 4         B
# 5         I
# 6         O
# 8         O
# 9         B
# 10        O
# 11        O
# 12        O
# 13        O
# 14        O

# %% [markdown]
# ## Remove stopwords

# %%
# Define a text string containing a sentence.
text = "aba123@ , Hello Prof.Nikshep, how are you doing?"

# Process the text using the spaCy language model loaded previously.
doc = nlp(text)

# Create a list comprehension to filter out tokens that are neither stop words nor punctuation.
non_stop = [t for t in doc if not t.is_stop and not t.is_punct]

# Print the list of non-stopword and non-punctuation tokens.
print(non_stop)
# Out:
# [aba123@, Hello, Prof., Nikshep]

# %% [markdown]
# ## Find the Nouns

# %%
# Define a text string containing a sentence.
text = "A.R Rehman music"

# Process the text using the spaCy language model loaded previously.
doc = nlp(text)

# Create a list comprehension to filter out tokens that are nouns or proper nouns.
nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]

# Print the list of tokens identified as nouns or proper nouns.
print(nouns)
# Out:
# [A.R, Rehman, music]

# %% [markdown]
# ## Names Entity Recognition (NER)

# %%
# Define a text string containing a sentence.
text = "Professor McCloud teaches gaming subject"

# Process the text using the spaCy language model loaded previously.
doc = nlp(text)

# Iterate through each named entity in the processed document and print its text and label.
for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (McCloud, PERSON)

# %% [markdown]
# ## Trying the harder one

# %%
# Define a text string containing a sentence.
text = "Mark Waters is the director of Mean Girls"

# Process the text using the spaCy language model loaded previously.
doc = nlp(text)

# Iterate through each named entity in the processed document and print its text and label.
for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Mark Waters, PERSON)

# %% [markdown]
#  ## Visualize NERs

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the spaCy document (doc) with entity visualization style and display it in Jupyter Notebook.
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Waters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the director of Mean Girls</div></span>

# %% [markdown]
#  ## Try on Real Dataset

# %% [markdown]
# ## install libraries

# %%
# !pip install html5lib
# !pip install --upgrade pip setuptools
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/8a/6a/19e9fe04fca059ccf770861c7d5721ab4c2aebc539889e97c7977528a53b/pip-24.0-py3-none-any.whl.metadata
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (68.0.0)
# Collecting setuptools
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/92/e1/1c8bb3420105e70bdf357d57dd5567202b4ef8d27f810e98bb962d950834/setuptools-69.2.0-py3-none-any.whl.metadata
#   Using cached setuptools-69.2.0-py3-none-any.whl.metadata (6.3 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# Using cached setuptools-69.2.0-py3-none-any.whl (821 kB)
# ERROR: To modify pip, please run the following command:
# C:\ProgramData\anaconda3\python.exe -m pip install --upgrade pip setuptools
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)

# %% [markdown]
# ##  Load Dataset - Article 1

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import re

# Define a function to extract text content from a given URL
def url_to_string(url):
    # Send a GET request to the URL
    res = requests.get(url)
    # Extract the HTML content
    html = res.text
    # Create a BeautifulSoup object to parse the HTML
    soup = BeautifulSoup(html, 'html5lib')
    # Remove unwanted elements like scripts, styles, and asides
    for script in soup(["script", "style", 'aside']):
        script.extract()
    # Extract the text content and join it into a single string
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# Use the defined function to fetch content from a given URL (in this case, the New York Times trending page)
ny_bb = url_to_string('https://openai.com/sora')

# Process the extracted text using the spaCy language model loaded previously
article = nlp(ny_bb)

# Calculate the number of named entities in the processed text
len(article.ents)
# Out:
# 242

# %% [markdown]
#  ## NERs

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the spaCy document (article) with entity visualization style and display it in Jupyter Notebook.
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora CloseSearch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Submit Skip to main contentSite NavigationResearchOverviewIndexGPT-4DALLÂ·E 3SoraAPIOverviewPricingDocsChatGPTOverviewTeamEnterprisePricingTry ChatGPTSafetyCompanyAboutBlogCareersResidencyCharterSecurityCustomer storiesSearch Navigation quick links
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Log inTry ChatGPTMenu Mobile Navigation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CloseSite NavigationResearchOverviewIndexGPT-4DALLÂ·E 3SoraAPIOverviewPricingDocsChatGPTOverviewTeamEnterprisePricingTry ChatGPTSafetyCompanyAboutBlogCareersResidencyCharterSecurityCustomer stories
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quick Links Log inTry ChatGPTSearch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  Submit
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CapabilitiesSafetyResearchSora Creating
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  video from text
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is an
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  model that can create realistic and imaginative scenes from text instructions.  Read technical report  All videos on this page were generated directly by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  without modification. PlayWeâre teaching
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  to understand and simulate the physical world in motion, with the goal of training models that help people solve problems that require real-world interaction.Introducing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , our text-to-video model.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  can generate videos
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to a minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  long while maintaining visual quality and adherence to the userâs prompt.1 of 9Prompt: A stylish woman walks down a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tokyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  street filled with warm glowing neon and animated city signage. She wears a black leather jacket, a long red dress, and black boots, and carries a black purse. She wears sunglasses and red lipstick. She walks confidently and casually. The street is damp and reflective, creating a mirror effect of the colorful lights. Many pedestrians walk about. more Prompt: A stylish woman walks down a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tokyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  street filled with warm glowing neon and animated city signage. She wears a black leather jacket, a long red dress, and black boots, and carries a black purse. She wears sunglasses and red lipstick. She walks confidently and casually. The street is damp and reflective, creating a mirror effect of the colorful lights. Many pedestrians walk about.0:00 / 0:00Prompt: Several giant wooly mammoths approach treading through a snowy meadow, their long wooly fur lightly blows in the wind as they walk, snow covered trees and dramatic snow capped mountains in the distance,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mid afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  light with wispy clouds and a sun high in the distance creates a warm glow, the low camera view is stunning capturing the large furry mammal with beautiful photography, depth of field. more Prompt: Several giant wooly mammoths approach treading through a snowy meadow, their long wooly fur lightly blows in the wind as they walk, snow covered trees and dramatic snow capped mountains in the distance,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mid afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  light with wispy clouds and a sun high in the distance creates a warm glow, the low camera view is stunning capturing the large furry mammal with beautiful photography, depth of field.0:00 / 0:00Prompt: A movie trailer featuring the adventures of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 30 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  space man wearing a red wool knitted motorcycle helmet, blue sky, salt desert, cinematic style, shot on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35mm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-

# %% [markdown]
#  ## Most popular NER Types

# %%
# Download the large English language model for spaCy if it hasn't been downloaded already.
# !python -m spacy download en_core_web_lg 

# Import the spaCy library
import spacy

# Load the downloaded English language model for spaCy
nlp = spacy.load("en_core_web_lg")

# Import Counter from collections module to count occurrences of each element
from collections import Counter

# Extract the labels of named entities from the processed text and count their occurrences
labels = [x.label_ for x in article.ents]
counter = Counter(labels)

# Print the count of each entity label
print(counter)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      --------------------------------------- 0.5/587.7 MB 16.0 MB/s eta 0:00:37
#      --------------------------------------- 2.6/587.7 MB 33.5 MB/s eta 0:00:18
#      --------------------------------------- 5.2/587.7 MB 41.5 MB/s eta 0:00:15
#      --------------------------------------- 7.2/587.7 MB 41.6 MB/s eta 0:00:14
#       -------------------------------------- 9.5/587.7 MB 43.5 MB/s eta 0:00:14
#       ------------------------------------- 11.5/587.7 MB 46.7 MB/s eta 0:00:13
#       ------------------------------------- 13.6/587.7 MB 46.7 MB/s eta 0:00:13
#       ------------------------------------- 15.2/587.7 MB 43.5 MB/s eta 0:00:14
#      - ------------------------------------ 17.6/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 19.7/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 21.8/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 23.9/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 25.9/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 27.9/587.7 MB 43.7 MB/s eta 0:00:13
#      - ------------------------------------ 29.9/587.7 MB 43.5 MB/s eta 0:00:13
#      -- ----------------------------------- 31.1/587.7 MB 40.9 MB/s eta 0:00:14
#      -- ----------------------------------- 33.5/587.7 MB 43.7 MB/s eta 0:00:13
#      -- ----------------------------------- 34.1/587.7 MB 36.4 MB/s eta 0:00:16
#      -- ----------------------------------- 35.8/587.7 MB 34.4 MB/s eta 0:00:17
#      -- ----------------------------------- 37.6/587.7 MB 34.4 MB/s eta 0:00:16
#      -- ----------------------------------- 39.6/587.7 MB 34.4 MB/s eta 0:00:16
#      -- ----------------------------------- 41.8/587.7 MB 36.4 MB/s eta 0:00:15
#      -- ----------------------------------- 43.6/587.7 MB 34.4 MB/s eta 0:00:16
#      -- ----------------------------------- 45.7/587.7 MB 40.9 MB/s eta 0:00:14
#      --- ---------------------------------- 47.5/587.7 MB 40.9 MB/s eta 0:00:14
#      --- ---------------------------------- 49.5/587.7 MB 40.9 MB/s eta 0:00:14
#      --- ---------------------------------- 51.5/587.7 MB 40.9 MB/s eta 0:00:14
#      --- ---------------------------------- 53.7/587.7 MB 40.9 MB/s eta 0:00:14
#      --- ---------------------------------- 55.8/587.7 MB 40.9 MB/s eta 0:00:13
#      --- ---------------------------------- 57.8/587.7 MB 43.7 MB/s eta 0:00:13
#      --- ---------------------------------- 60.0/587.7 MB 43.5 MB/s eta 0:00:13
#      ---- --------------------------------- 62.0/587.7 MB 43.5 MB/s eta 0:00:13
#      ---- --------------------------------- 63.0/587.7 MB 43.7 MB/s eta 0:00:13
#      ---- --------------------------------- 64.9/587.7 MB 40.9 MB/s eta 0:00:13
#      ---- --------------------------------- 67.1/587.7 MB 38.6 MB/s eta 0:00:14
#      ---- --------------------------------- 69.3/587.7 MB 40.9 MB/s eta 0:00:13
#      ---- --------------------------------- 71.4/587.7 MB 38.5 MB/s eta 0:00:14
#      ---- --------------------------------- 73.5/587.7 MB 46.9 MB/s eta 0:00:11
#      ---- --------------------------------- 75.3/587.7 MB 43.5 MB/s eta 0:00:12
#      ----- -------------------------------- 77.6/587.7 MB 46.7 MB/s eta 0:00:11
#      ----- -------------------------------- 79.3/587.7 MB 43.7 MB/s eta 0:00:12
#      ----- -------------------------------- 81.4/587.7 MB 43.5 MB/s eta 0:00:12
#      ----- -------------------------------- 83.6/587.7 MB 43.5 MB/s eta 0:00:12
#      ----- -------------------------------- 85.8/587.7 MB 43.7 MB/s eta 0:00:12
#      ----- -------------------------------- 86.7/587.7 MB 36.3 MB/s eta 0:00:14
#      ----- -------------------------------- 87.5/587.7 MB 32.7 MB/s eta 0:00:16
#      ----- -------------------------------- 90.6/587.7 MB 38.5 MB/s eta 0:00:13
#      ------ ------------------------------- 93.9/587.7 MB 43.5 MB/s eta 0:00:12
#      ------ ------------------------------- 96.0/587.7 MB 43.5 MB/s eta 0:00:12
#      ------ ------------------------------- 97.6/587.7 MB 54.7 MB/s eta 0:00:09
#      ------ ------------------------------ 100.5/587.7 MB 54.7 MB/s eta 0:00:09
#      ------ ------------------------------ 102.7/587.7 MB 50.4 MB/s eta 0:00:10
#      ------ ------------------------------ 105.0/587.7 MB 46.7 MB/s eta 0:00:11
#      ------ ------------------------------ 107.0/587.7 MB 46.7 MB/s eta 0:00:11
#      ------ ------------------------------ 109.1/587.7 MB 46.9 MB/s eta 0:00:11
#      ------ ------------------------------ 111.2/587.7 MB 46.7 MB/s eta 0:00:11
#      ------- ----------------------------- 113.2/587.7 MB 46.7 MB/s eta 0:00:11
#      ------- ----------------------------- 115.2/587.7 MB 43.7 MB/s eta 0:00:11
#      ------- ----------------------------- 117.3/587.7 MB 46.9 MB/s eta 0:00:11
#      ------- ----------------------------- 119.3/587.7 MB 46.7 MB/s eta 0:00:11
#      ------- ----------------------------- 121.4/587.7 MB 46.7 MB/s eta 0:00:10
#      ------- ----------------------------- 123.4/587.7 MB 46.7 MB/s eta 0:00:10
#      ------- ----------------------------- 125.4/587.7 MB 43.5 MB/s eta 0:00:11
#      -------- ---------------------------- 127.5/587.7 MB 46.7 MB/s eta 0:00:10
#      -------- ---------------------------- 129.6/587.7 MB 46.7 MB/s eta 0:00:10
#      -------- ---------------------------- 131.5/587.7 MB 43.7 MB/s eta 0:00:11
#      -------- ---------------------------- 133.7/587.7 MB 46.9 MB/s eta 0:00:10
#      -------- ---------------------------- 135.8/587.7 MB 46.7 MB/s eta 0:00:10
#      -------- ---------------------------- 137.6/587.7 MB 43.7 MB/s eta 0:00:11
#      -------- ---------------------------- 139.9/587.7 MB 46.7 MB/s eta 0:00:10
#      -------- ---------------------------- 141.6/587.7 MB 43.5 MB/s eta 0:00:11
#      --------- --------------------------- 143.3/587.7 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 145.1/587.7 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 146.3/587.7 MB 38.6 MB/s eta 0:00:12
#      --------- --------------------------- 147.9/587.7 MB 36.4 MB/s eta 0:00:13
#      --------- --------------------------- 149.4/587.7 MB 34.4 MB/s eta 0:00:13
#      --------- --------------------------- 152.6/587.7 MB 38.5 MB/s eta 0:00:12
#      --------- --------------------------- 155.5/587.7 MB 46.7 MB/s eta 0:00:10
#      --------- --------------------------- 157.9/587.7 MB 54.4 MB/s eta 0:00:08
#      ---------- -------------------------- 160.0/587.7 MB 59.5 MB/s eta 0:00:08
#      ---------- -------------------------- 161.1/587.7 MB 50.1 MB/s eta 0:00:09
#      ---------- -------------------------- 163.0/587.7 MB 43.7 MB/s eta 0:00:10
#      ---------- -------------------------- 165.3/587.7 MB 43.7 MB/s eta 0:00:10
#      ---------- -------------------------- 167.7/587.7 MB 40.9 MB/s eta 0:00:11
#      ---------- -------------------------- 169.9/587.7 MB 40.9 MB/s eta 0:00:11
#      ---------- -------------------------- 172.0/587.7 MB 46.7 MB/s eta 0:00:09
#      ---------- -------------------------- 173.8/587.7 MB 46.7 MB/s eta 0:00:09
#      ----------- ------------------------- 175.9/587.7 MB 40.9 MB/s eta 0:00:11
#      ----------- ------------------------- 178.3/587.7 MB 43.7 MB/s eta 0:00:10
#      ----------- ------------------------- 181.1/587.7 MB 43.7 MB/s eta 0:00:10
#      ----------- ------------------------- 183.2/587.7 MB 46.7 MB/s eta 0:00:09
#      ----------- ------------------------- 185.4/587.7 MB 50.4 MB/s eta 0:00:08
#      ----------- ------------------------- 187.5/587.7 MB 43.7 MB/s eta 0:00:10
#      ----------- ------------------------- 189.1/587.7 MB 38.6 MB/s eta 0:00:11
#      ----------- ------------------------- 189.8/587.7 MB 31.2 MB/s eta 0:00:13
#      ------------ ------------------------ 190.8/587.7 MB 28.4 MB/s eta 0:00:14
#      ------------ ------------------------ 192.4/587.7 MB 26.2 MB/s eta 0:00:16
#      ------------ ------------------------ 194.2/587.7 MB 26.2 MB/s eta 0:00:16
#      ------------ ------------------------ 195.4/587.7 MB 23.4 MB/s eta 0:00:17
#      ------------ ------------------------ 196.1/587.7 MB 22.6 MB/s eta 0:00:18
#      ------------ ------------------------ 197.9/587.7 MB 22.6 MB/s eta 0:00:18
#      ------------ ------------------------ 199.6/587.7 MB 23.4 MB/s eta 0:00:17
#      ------------ ------------------------ 201.1/587.7 MB 26.2 MB/s eta 0:00:15
#      ------------ ------------------------ 202.6/587.7 MB 25.1 MB/s eta 0:00:16
#      ------------ ------------------------ 203.4/587.7 MB 23.4 MB/s eta 0:00:17
#      ------------ ------------------------ 205.2/587.7 MB 23.4 MB/s eta 0:00:17
#      ------------- ----------------------- 207.5/587.7 MB 29.7 MB/s eta 0:00:13
#      ------------- ----------------------- 210.3/587.7 MB 34.4 MB/s eta 0:00:11
#      ------------- ----------------------- 212.8/587.7 MB 40.9 MB/s eta 0:00:10
#      ------------- ----------------------- 215.6/587.7 MB 59.8 MB/s eta 0:00:07
#      ------------- ----------------------- 217.5/587.7 MB 54.7 MB/s eta 0:00:07
#      ------------- ----------------------- 219.3/587.7 MB 50.4 MB/s eta 0:00:08
#      ------------- ----------------------- 221.4/587.7 MB 46.7 MB/s eta 0:00:08
#      -------------- ---------------------- 223.3/587.7 MB 46.7 MB/s eta 0:00:08
#      -------------- ---------------------- 224.6/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 227.0/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 229.6/587.7 MB 46.7 MB/s eta 0:00:08
#      -------------- ---------------------- 232.2/587.7 MB 50.4 MB/s eta 0:00:08
#      -------------- ---------------------- 234.4/587.7 MB 50.4 MB/s eta 0:00:08
#      -------------- ---------------------- 237.2/587.7 MB 54.7 MB/s eta 0:00:07
#      --------------- --------------------- 239.7/587.7 MB 54.7 MB/s eta 0:00:07
#      --------------- --------------------- 242.6/587.7 MB 54.4 MB/s eta 0:00:07
#      --------------- --------------------- 244.3/587.7 MB 50.4 MB/s eta 0:00:07
#      --------------- --------------------- 246.6/587.7 MB 50.4 MB/s eta 0:00:07
#      --------------- --------------------- 249.5/587.7 MB 50.1 MB/s eta 0:00:07
#      --------------- --------------------- 251.3/587.7 MB 46.9 MB/s eta 0:00:08
#      --------------- --------------------- 254.0/587.7 MB 50.4 MB/s eta 0:00:07
#      ---------------- -------------------- 255.2/587.7 MB 43.5 MB/s eta 0:00:08
#      ---------------- -------------------- 257.8/587.7 MB 43.5 MB/s eta 0:00:08
#      ---------------- -------------------- 260.2/587.7 MB 43.5 MB/s eta 0:00:08
#      ---------------- -------------------- 263.5/587.7 MB 50.4 MB/s eta 0:00:07
#      ---------------- -------------------- 267.1/587.7 MB 65.6 MB/s eta 0:00:05
#      ---------------- -------------------- 269.2/587.7 MB 65.6 MB/s eta 0:00:05
#      ----------------- ------------------- 272.6/587.7 MB 65.6 MB/s eta 0:00:05
#      ----------------- ------------------- 275.5/587.7 MB 65.6 MB/s eta 0:00:05
#      ----------------- ------------------- 278.7/587.7 MB 65.6 MB/s eta 0:00:05
#      ----------------- ------------------- 280.5/587.7 MB 59.5 MB/s eta 0:00:06
#      ----------------- ------------------- 283.2/587.7 MB 59.5 MB/s eta 0:00:06
#      ------------------ ------------------ 286.0/587.7 MB 59.8 MB/s eta 0:00:06
#      ------------------ ------------------ 288.1/587.7 MB 50.4 MB/s eta 0:00:06
#      ------------------ ------------------ 291.1/587.7 MB 59.5 MB/s eta 0:00:05
#      ------------------ ------------------ 293.8/587.7 MB 59.5 MB/s eta 0:00:05
#      ------------------ ------------------ 296.3/587.7 MB 59.5 MB/s eta 0:00:05
#      ------------------ ------------------ 298.4/587.7 MB 59.5 MB/s eta 0:00:05
#      ------------------ ------------------ 300.7/587.7 MB 50.4 MB/s eta 0:00:06
#      ------------------- ----------------- 303.1/587.7 MB 46.7 MB/s eta 0:00:07
#      ------------------- ----------------- 305.2/587.7 MB 46.7 MB/s eta 0:00:07
#      ------------------- ----------------- 307.2/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------- ----------------- 309.2/587.7 MB 46.7 MB/s eta 0:00:06
#      ------------------- ----------------- 311.2/587.7 MB 46.7 MB/s eta 0:00:06
#      ------------------- ----------------- 311.5/587.7 MB 38.5 MB/s eta 0:00:08
#      ------------------- ----------------- 312.7/587.7 MB 34.6 MB/s eta 0:00:08
#      ------------------- ----------------- 316.7/587.7 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 318.4/587.7 MB 46.7 MB/s eta 0:00:06
#      -------------------- ---------------- 319.8/587.7 MB 36.4 MB/s eta 0:00:08
#      -------------------- ---------------- 321.8/587.7 MB 50.4 MB/s eta 0:00:06
#      -------------------- ---------------- 322.3/587.7 MB 46.7 MB/s eta 0:00:06
#      -------------------- ---------------- 322.3/587.7 MB 46.7 MB/s eta 0:00:06
#      -------------------- ---------------- 325.3/587.7 MB 34.4 MB/s eta 0:00:08
#      -------------------- ---------------- 326.3/587.7 MB 29.7 MB/s eta 0:00:09
#      -------------------- ---------------- 327.8/587.7 MB 25.2 MB/s eta 0:00:11
#      -------------------- ---------------- 329.8/587.7 MB 27.3 MB/s eta 0:00:10
#      -------------------- ---------------- 332.4/587.7 MB 28.5 MB/s eta 0:00:09
#      --------------------- --------------- 335.7/587.7 MB 36.4 MB/s eta 0:00:07
#      --------------------- --------------- 338.9/587.7 MB 65.2 MB/s eta 0:00:04
#      --------------------- --------------- 341.1/587.7 MB 59.5 MB/s eta 0:00:05
#      --------------------- --------------- 342.9/587.7 MB 54.7 MB/s eta 0:00:05
#      --------------------- --------------- 346.4/587.7 MB 59.5 MB/s eta 0:00:05
#      ---------------------- -------------- 350.1/587.7 MB 59.5 MB/s eta 0:00:04
#      ---------------------- -------------- 352.0/587.7 MB 59.5 MB/s eta 0:00:04
#      ---------------------- -------------- 354.2/587.7 MB 59.5 MB/s eta 0:00:04
#      ---------------------- -------------- 356.5/587.7 MB 54.4 MB/s eta 0:00:05
#      ---------------------- -------------- 358.6/587.7 MB 46.7 MB/s eta 0:00:05
#      ---------------------- -------------- 360.6/587.7 MB 43.5 MB/s eta 0:00:06
#      ---------------------- -------------- 362.6/587.7 MB 43.7 MB/s eta 0:00:06
#      ---------------------- -------------- 364.7/587.7 MB 43.7 MB/s eta 0:00:06
#      ----------------------- ------------- 366.5/587.7 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 367.3/587.7 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 368.8/587.7 MB 36.4 MB/s eta 0:00:07
#      ----------------------- ------------- 370.9/587.7 MB 36.4 MB/s eta 0:00:06
#      ----------------------- ------------- 373.4/587.7 MB 38.5 MB/s eta 0:00:06
#      ----------------------- ------------- 375.5/587.7 MB 38.5 MB/s eta 0:00:06
#      ----------------------- ------------- 377.9/587.7 MB 43.7 MB/s eta 0:00:05
#      ----------------------- ------------- 379.6/587.7 MB 46.9 MB/s eta 0:00:05
#      ------------------------ ------------ 382.1/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------ ------------ 384.9/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------ ------------ 386.9/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------ ------------ 389.0/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------ ------------ 391.0/587.7 MB 50.4 MB/s eta 0:00:04
#      ------------------------ ------------ 393.1/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------ ------------ 394.9/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------ ------------ 397.0/587.7 MB 40.9 MB/s eta 0:00:05
#      ------------------------- ----------- 399.2/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------- ----------- 401.2/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------- ----------- 403.4/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------- ----------- 405.5/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------- ----------- 407.5/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------- ----------- 409.6/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------- ----------- 411.4/587.7 MB 43.7 MB/s eta 0:00:05
#      -------------------------- ---------- 413.4/587.7 MB 40.9 MB/s eta 0:00:05
#      -------------------------- ---------- 415.4/587.7 MB 43.7 MB/s eta 0:00:04
#      -------------------------- ---------- 417.6/587.7 MB 43.7 MB/s eta 0:00:04
#      -------------------------- ---------- 419.2/587.7 MB 40.9 MB/s eta 0:00:05
#      -------------------------- ---------- 420.9/587.7 MB 38.6 MB/s eta 0:00:05
#      -------------------------- ---------- 422.6/587.7 MB 38.6 MB/s eta 0:00:05
#      -------------------------- ---------- 424.2/587.7 MB 38.5 MB/s eta 0:00:05
#      -------------------------- ---------- 425.9/587.7 MB 38.6 MB/s eta 0:00:05
#      -------------------------- ---------- 428.6/587.7 MB 40.9 MB/s eta 0:00:04
#      --------------------------- --------- 430.4/587.7 MB 40.9 MB/s eta 0:00:04
#      --------------------------- --------- 432.4/587.7 MB 43.7 MB/s eta 0:00:04
#      --------------------------- --------- 434.8/587.7 MB 50.4 MB/s eta 0:00:04
#      --------------------------- --------- 436.6/587.7 MB 46.7 MB/s eta 0:00:04
#      --------------------------- --------- 438.4/587.7 MB 43.5 MB/s eta 0:00:04
#      --------------------------- --------- 440.3/587.7 MB 43.5 MB/s eta 0:00:04
#      --------------------------- --------- 442.7/587.7 MB 43.7 MB/s eta 0:00:04
#      ---------------------------- -------- 444.9/587.7 MB 43.7 MB/s eta 0:00:04
#      ---------------------------- -------- 447.3/587.7 MB 46.7 MB/s eta 0:00:04
#      ---------------------------- -------- 449.5/587.7 MB 50.4 MB/s eta 0:00:03
#      ---------------------------- -------- 451.6/587.7 MB 46.7 MB/s eta 0:00:03
#      ---------------------------- -------- 453.3/587.7 MB 46.7 MB/s eta 0:00:03
#      ---------------------------- -------- 455.0/587.7 MB 43.5 MB/s eta 0:00:04
#      ---------------------------- -------- 456.9/587.7 MB 40.9 MB/s eta 0:00:04
#      ---------------------------- -------- 458.6/587.7 MB 38.6 MB/s eta 0:00:04
#      ----------------------------- ------- 460.8/587.7 MB 40.9 MB/s eta 0:00:04
#      ----------------------------- ------- 462.8/587.7 MB 36.4 MB/s eta 0:00:04
#      ----------------------------- ------- 465.1/587.7 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 467.6/587.7 MB 43.5 MB/s eta 0:00:03
#      ----------------------------- ------- 470.6/587.7 MB 46.9 MB/s eta 0:00:03
#      ----------------------------- ------- 473.0/587.7 MB 54.7 MB/s eta 0:00:03
#      ----------------------------- ------- 475.1/587.7 MB 54.7 MB/s eta 0:00:03
#      ------------------------------ ------ 477.0/587.7 MB 50.4 MB/s eta 0:00:03
#      ------------------------------ ------ 478.2/587.7 MB 46.7 MB/s eta 0:00:03
#      ------------------------------ ------ 479.7/587.7 MB 43.5 MB/s eta 0:00:03
#      ------------------------------ ------ 481.3/587.7 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 482.5/587.7 MB 34.4 MB/s eta 0:00:04
#      ------------------------------ ------ 485.1/587.7 MB 36.4 MB/s eta 0:00:03
#      ------------------------------ ------ 487.5/587.7 MB 38.6 MB/s eta 0:00:03
#      ------------------------------ ------ 489.6/587.7 MB 40.9 MB/s eta 0:00:03
#      ------------------------------ ------ 492.1/587.7 MB 46.7 MB/s eta 0:00:03
#      ------------------------------- ----- 494.2/587.7 MB 50.4 MB/s eta 0:00:02
#      ------------------------------- ----- 496.1/587.7 MB 46.7 MB/s eta 0:00:02
#      ------------------------------- ----- 497.4/587.7 MB 43.5 MB/s eta 0:00:03
#      ------------------------------- ----- 498.7/587.7 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 500.2/587.7 MB 38.6 MB/s eta 0:00:03
#      ------------------------------- ----- 501.7/587.7 MB 32.7 MB/s eta 0:00:03
#      ------------------------------- ----- 504.3/587.7 MB 34.4 MB/s eta 0:00:03
#      ------------------------------- ----- 506.7/587.7 MB 36.3 MB/s eta 0:00:03
#      -------------------------------- ---- 509.2/587.7 MB 43.5 MB/s eta 0:00:02
#      -------------------------------- ---- 511.8/587.7 MB 54.7 MB/s eta 0:00:02
#      -------------------------------- ---- 514.4/587.7 MB 54.7 MB/s eta 0:00:02
#      -------------------------------- ---- 516.3/587.7 MB 46.7 MB/s eta 0:00:02
#      -------------------------------- ---- 517.9/587.7 MB 43.5 MB/s eta 0:00:02
#      -------------------------------- ---- 519.6/587.7 MB 38.6 MB/s eta 0:00:02
#      -------------------------------- ---- 521.6/587.7 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 524.0/587.7 MB 36.4 MB/s eta 0:00:02
#      --------------------------------- --- 526.3/587.7 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 529.1/587.7 MB 50.4 MB/s eta 0:00:02
#      --------------------------------- --- 532.0/587.7 MB 54.4 MB/s eta 0:00:02
#      --------------------------------- --- 535.5/587.7 MB 65.6 MB/s eta 0:00:01
#      --------------------------------- --- 537.9/587.7 MB 65.6 MB/s eta 0:00:01
#      --------------------------------- --- 539.7/587.7 MB 59.5 MB/s eta 0:00:01
#      ---------------------------------- -- 541.1/587.7 MB 50.4 MB/s eta 0:00:01
#      ---------------------------------- -- 543.6/587.7 MB 46.7 MB/s eta 0:00:01
#      ---------------------------------- -- 546.4/587.7 MB 43.7 MB/s eta 0:00:01
#      ---------------------------------- -- 548.3/587.7 MB 40.9 MB/s eta 0:00:01
#      ---------------------------------- -- 550.2/587.7 MB 43.7 MB/s eta 0:00:01
#      ---------------------------------- -- 552.3/587.7 MB 43.7 MB/s eta 0:00:01
#      ---------------------------------- -- 554.5/587.7 MB 43.7 MB/s eta 0:00:01
#      ---------------------------------- -- 555.4/587.7 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 555.9/587.7 MB 38.6 MB/s eta 0:00:01
#      ----------------------------------- - 555.9/587.7 MB 38.6 MB/s eta 0:00:01
#      ----------------------------------- - 557.4/587.7 MB 29.8 MB/s eta 0:00:02
#      ----------------------------------- - 560.5/587.7 MB 31.2 MB/s eta 0:00:01
#      ----------------------------------- - 560.5/587.7 MB 31.2 MB/s eta 0:00:01
#      ----------------------------------- - 562.3/587.7 MB 26.2 MB/s eta 0:00:01
#      ----------------------------------- - 563.8/587.7 MB 25.1 MB/s eta 0:00:01
#      ----------------------------------- - 565.3/587.7 MB 24.3 MB/s eta 0:00:01
#      ----------------------------------- - 567.9/587.7 MB 34.4 MB/s eta 0:00:01
#      ----------------------------------- - 570.9/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  573.7/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  576.7/587.7 MB 59.5 MB/s eta 0:00:01
#      ------------------------------------  579.6/587.7 MB 65.6 MB/s eta 0:00:01
#      ------------------------------------  581.7/587.7 MB 54.4 MB/s eta 0:00:01
#      ------------------------------------  583.9/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  586.6/587.7 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 50.4 MB/s eta 0:00:01
#      -------------------------------------- 587.7/587.7 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Counter({'PERSON': 61, 'GPE': 58, 'ORG': 36, 'DATE': 19, 'PRODUCT': 12, 'TIME': 11, 'NORP': 10, 'CARDINAL': 9, 'QUANTITY': 7, 'LOC': 7, 'FAC': 6, 'WORK_OF_ART': 3, 'ORDINAL': 2, 'MONEY': 1})

# %% [markdown]
#  ## Most popular NER

# %%
# Extract the text of named entities from the processed text and count their occurrences
items = [x.text for x in article.ents]
counter_items = Counter(items)

# Get the five most common named entities and their counts
most_common_entities = counter_items.most_common(5)

# Print the result
print(most_common_entities)
# Out:
# [('Sora', 18), ('Tokyo', 6), ('35mm', 5), ('cliffâ\x80\x99s', 4), ('birdâ\x80\x99s', 4)]

# %% [markdown]
#  ## Printing Sentences

# %%
# Import the spaCy library
import spacy

# Load the English language model for spaCy
nlp = spacy.load("en_core_web_lg")

# Extract sentences containing named entities from the processed text
sentences = [x for x in article.ents]

# Print the 21st sentence containing named entities
print(sentences[1:13])
# Out:
# [Log inTry ChatGPTMenu Mobile Navigation, Quick Links Log inTry ChatGPTSearch, CapabilitiesSafetyResearchSora Creating, Sora, AI, Sora, AI, Sora, Sora, up to a minute, Tokyo, Tokyo]

# %% [markdown]
#  ## NER Tages

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the 21st sentence containing named entities with entity visualization style
displacy.render(nlp(str(sentences[1:13])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Log inTry ChatGPTMenu Mobile Navigation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Quick Links Log inTry ChatGPTSearch,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CapabilitiesSafetyResearchSora Creating
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to a minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tokyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tokyo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ]</div></span>

# %% [markdown]
# ## Types of words in the sentence

# %%
# Extract non-stopword and non-punctuation tokens from the 21st sentence containing named entities
tokens_info = [(x.orth_, x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences[1:13])) if not y.is_stop and y.pos_ != 'PUNCT']]

# Print the tokens' orthographic form, part-of-speech, and lemma
print(tokens_info)
# Out:
# [('Log', 'NOUN', 'log'), ('inTry', 'NOUN', 'intry'), ('ChatGPTMenu', 'PROPN', 'ChatGPTMenu'), ('Mobile', 'PROPN', 'Mobile'), ('Navigation', 'PROPN', 'Navigation'), ('Quick', 'PROPN', 'Quick'), ('Links', 'NOUN', 'link'), ('Log', 'VERB', 'log'), ('inTry', 'NOUN', 'intry'), ('ChatGPTSearch', 'PROPN', 'ChatGPTSearch'), ('CapabilitiesSafetyResearchSora', 'PROPN', 'CapabilitiesSafetyResearchSora'), ('Creating', 'PROPN', 'Creating'), ('Sora', 'PROPN', 'Sora'), ('AI', 'PROPN', 'AI'), ('Sora', 'PROPN', 'Sora'), ('AI', 'PROPN', 'AI'), ('Sora', 'PROPN', 'Sora'), ('Sora', 'PROPN', 'Sora'), ('minute', 'NOUN', 'minute'), ('Tokyo', 'PROPN', 'Tokyo'), ('Tokyo', 'PROPN', 'Tokyo')]

# %% [markdown]
#  ## Sentence Dependency Tree

# %%
# Import the displacy module from spaCy for dependency visualization.
from spacy import displacy

# Render the dependency parse of the 21st sentence containing named entities and display it in Jupyter Notebook.
# Adjust the distance between tokens for better visualization.
displacy.render(nlp(str(sentences[1:5])), style='dep', jupyter=True, options={'distance': 150})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a62f8f75eb9e4098a5711583ebea5164-0" class="displacy" width="2150" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Log</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">inTry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">ChatGPTMenu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Mobile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Navigation,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Links</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Log</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">inTry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">ChatGPTSearch,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">CapabilitiesSafetyResearchSora</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Creating,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Sora]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-0" stroke-width="2px" d="M70,377.0 C70,2.0 1250.0,2.0 1250.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,379.0 L62,367.0 78,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-1" stroke-width="2px" d="M70,377.0 C70,302.0 180.0,302.0 180.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180.0,379.0 L188.0,367.0 172.0,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-2" stroke-width="2px" d="M370,377.0 C370,152.0 790.0,152.0 790.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,379.0 L362,367.0 378,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-3" stroke-width="2px" d="M520,377.0 C520,227.0 785.0,227.0 785.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,379.0 L512,367.0 528,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-4" stroke-width="2px" d="M670,377.0 C670,302.0 780.0,302.0 780.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,379.0 L662,367.0 678,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-5" stroke-width="2px" d="M220,377.0 C220,77.0 795.0,77.0 795.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M795.0,379.0 L803.0,367.0 787.0,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a62f8f75eb9e4098a5711583ebea5164-0-6" stroke-width="2px" d="M970,377.0 C970,302.0 1080.0,302.0 1080.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a62f8f75eb9e4098a5711583ebea5164-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M970,379.0 L962,367.0 978,367.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6

# %% [markdown]
#  ## Load Dataset - Article 2

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import re

# Define a function to extract text content from a given URL
def url_to_string(url):
    # Send a GET request to the URL
    res = requests.get(url)
    # Extract the HTML content
    html = res.text
    # Create a BeautifulSoup object to parse the HTML
    soup = BeautifulSoup(html, 'html5lib')
    # Remove unwanted elements like scripts, styles, and asides
    for script in soup(["script", "style", 'aside']):
        script.extract()
    # Extract the text content and join it into a single string
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# Use the defined function to fetch content from a given URL (in this case, the New York Times trending page)
ny_bb = url_to_string('https://www.cnn.com/')

# Process the extracted text using the spaCy language model loaded previously
article = nlp(ny_bb)

# Calculate the number of named entities in the processed text
len(article.ents)
# Out:
# 334

# %% [markdown]
#  ## NERs

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the spaCy document (article) with entity visualization style and display it in Jupyter Notebook.
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breaking News, Latest News and Videos |
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  values your feedback
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . How relevant is this ad to you?
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Did you encounter any technical issues?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Video player was slow to load content                                                                                                                                                                                                                                                                                                                                                             Video content never loaded                                                                                                                                                                                                                                                                                                                                                             Ad froze or did not finish loading                                                                                                                                                                                                                                                                                                                                                             Video content did not start after ad                                                                                                                                                                                                                                                                                                                                                             Audio on ad was too loud                                                                                                                                                                                                                                                                                                                                                             Other issues                                                                                                                                                                                                                                                                                                                                                                                                                                                               Ad never loaded                                                                                                                                                                                                                                                                                                                                                             Ad prevented/slowed the page from loading                                                                                                                                                                                                                                                                                                                                                             Content moved around while ad loaded

# %% [markdown]
# ## Most Popular NER types

# %%
# Import the spaCy library
import spacy

# Load the downloaded English language model for spaCy
nlp = spacy.load("en_core_web_lg")

# Import Counter from collections module to count occurrences of each element
from collections import Counter

# Extract the labels of named entities from the processed text and count their occurrences
labels = [x.label_ for x in article.ents]
counter = Counter(labels)

# Print the count of each entity label
print(counter)
# Out:
# Counter({'ORG': 86, 'PERSON': 78, 'GPE': 47, 'EVENT': 28, 'CARDINAL': 27, 'DATE': 25, 'WORK_OF_ART': 13, 'NORP': 11, 'PRODUCT': 6, 'MONEY': 6, 'LOC': 3, 'ORDINAL': 2, 'TIME': 1, 'QUANTITY': 1})

# %%
# Extract the text of named entities from the processed text and count their occurrences
items = [x.text for x in article.ents]
counter_items = Counter(items)

# Get the five most common named entities and their counts
most_common_entities = counter_items.most_common(5)

# Print the result
print(most_common_entities)
# Out:
# [('CNN', 30), ('US', 10), ('Trump', 8), ('Baltimore', 4), ('Amazon', 4)]

# %% [markdown]
#  ## Printing Sentences

# %%
# Import the spaCy library
import spacy

# Load the English language model for spaCy
nlp = spacy.load("en_core_web_lg")

# Extract sentences containing named entities from the processed text
sentences = [x for x in article.ents]

# Print the 21st sentence containing named entities
print(sentences[1:13])
# Out:
# [CNN, CNN, 1, 2, US, World                                                                                                      Politics                                                                                                      Business                                                                                                      Opinion                                                                                                      Health, World                                                           Politics                                                           Business                                                           Opinion                                                           Health                                                           Entertainment                                                           Style                                                           Travel                                                           Sports                                                           Underscored                                                                                                                     Watch                                   Listen                                   Live TV                                                                                                                                  Sign, CNN, CNN, CNN, CNN, US]

# %% [markdown]
# ## NER Tags

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the 21st sentence containing named entities with entity visualization style
displacy.render(nlp(str(sentences[1:13])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World                                                                                                      Politics                                                                                                      Business                                                                                                      Opinion                                                                                                      Health, World                                                           Politics                                                           Business                                                           Opinion                                                           Health                                                           Entertainment                                                           Style                                                           Travel                                                           Sports                                                           Underscored                                                                                                                     Watch                                   Listen                                   Live TV                                                                                                                                  Sign
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ]</div></span>

# %% [markdown]
#  ## Types of words in the Sentence

# %%
# Extract non-stopword and non-punctuation tokens from the 21st sentence containing named entities
tokens_info = [(x.orth_, x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences[1:13])) if not y.is_stop and y.pos_ != 'PUNCT']]

# Print the tokens' orthographic form, part-of-speech, and lemma
print(tokens_info)
# Out:
# [('[', 'X', '['), ('CNN', 'PROPN', 'CNN'), ('CNN', 'PROPN', 'CNN'), ('1', 'NUM', '1'), ('2', 'NUM', '2'), ('World', 'PROPN', 'World'), ('                                                                                                     ', 'SPACE', '                                                                                                     '), ('Politics', 'PROPN', 'Politics'), ('                                                                                                     ', 'SPACE', '                                                                                                     '), ('Business', 'PROPN', 'Business'), ('                                                                                                     ', 'SPACE', '                                                                                                     '), ('Opinion', 'PROPN', 'Opinion'), ('                                                                                                     ', 'SPACE', '                                                                                                     '), ('Health', 'PROPN', 'Health'), ('World', 'PROPN', 'World'), ('                                                          ', 'SPACE', '                                                          '), ('Politics', 'PROPN', 'Politics'), ('                                                          ', 'SPACE', '                                                          '), ('Business', 'PROPN', 'Business'), ('                                                          ', 'SPACE', '                                                          '), ('Opinion', 'PROPN', 'Opinion'), ('                                                          ', 'SPACE', '                                                          '), ('Health', 'PROPN', 'Health'), ('                                                          ', 'SPACE', '                                                          '), ('Entertainment', 'PROPN', 'Entertainment'), ('                                                          ', 'SPACE', '                                                          '), ('Style', 'PROPN', 'Style'), ('                                                          ', 'SPACE', '                                                          '), ('Travel', 'PROPN', 'Travel'), ('                                                          ', 'SPACE', '                                                          '), ('Sports', 'PROPN', 'Sports'), ('                                                          ', 'SPACE', '                                                          '), ('Underscored', 'PROPN', 'Underscored'), ('                                                                                                                    ', 'SPACE', '                                                                                                                    '), ('Watch', 'PROPN', 'Watch'), ('                                  ', 'SPACE', '                                  '), ('Listen', 'VERB', 'listen'), ('                                  ', 'SPACE', '                                  '), ('Live', 'ADJ', 'live'), ('TV', 'NOUN', 'tv'), ('                                                                                                                                 ', 'SPACE', '                                                                                                                                 '), ('Sign', 'PROPN', 'Sign'), ('CNN', 'PROPN', 'CNN'), ('CNN', 'PROPN', 'CNN'), ('CNN', 'PROPN', 'CNN'), ('CNN', 'PROPN', 'CNN')]

# %% [markdown]
#  ## Sentence Dependency Tree

# %%
# Import the displacy module from spaCy for dependency visualization.
from spacy import displacy

# Render the dependency parse of the 21st sentence containing named entities and display it in Jupyter Notebook.
# Adjust the distance between tokens for better visualization.
displacy.render(nlp(str(sentences[1:3])), style='dep', jupyter=True, options={'distance': 150})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="82d78987b6f142428dc12299fe8d89bd-0" class="displacy" width="500" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">CNN,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">CNN]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d78987b6f142428dc12299fe8d89bd-0-0" stroke-width="2px" d="M70,152.0 C70,2.0 350.0,2.0 350.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d78987b6f142428dc12299fe8d89bd-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d78987b6f142428dc12299fe8d89bd-0-1" stroke-width="2px" d="M220,152.0 C220,77.0 345.0,77.0 345.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d78987b6f142428dc12299fe8d89bd-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,154.0 L212,142.0 228,142.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
#  ## Load Dataset - Article 3

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import re

# Define a function to extract text content from a given URL
def url_to_string(url):
    # Send a GET request to the URL
    res = requests.get(url)
    # Extract the HTML content
    html = res.text
    # Create a BeautifulSoup object to parse the HTML
    soup = BeautifulSoup(html, 'html5lib')
    # Remove unwanted elements like scripts, styles, and asides
    for script in soup(["script", "style", 'aside']):
        script.extract()
    # Extract the text content and join it into a single string
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# Use the defined function to fetch content from a given URL (in this case, the New York Times trending page)
ny_bb = url_to_string('https://www.timessquarenyc.org/')

# Process the extracted text using the spaCy language model loaded previously
article = nlp(ny_bb)

# Calculate the number of named entities in the processed text
len(article.ents)
# Out:
# 117

# %% [markdown]
#  ## NERs

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the spaCy document (article) with entity visualization style and display it in Jupyter Notebook.
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times Square NYC                            Skip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to main content                                                                                                                                                                        &gt; &gt; &gt;                                                                                                                                                                                         Art           at
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midnight           Midnight Moment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#            Each month, a new work of art takes over 95+ screens in
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just before
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  midnight                      http://arts.timessquarenyc.org/times-square-arts/projects/midnight-moment/storms/index.aspx           left                                          Art             at
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midnight Moment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Each month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a new work of art takes over 95+ screens in
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just before
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     midnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Affordable           Times Square           Affordable Times Square Guide           Happy hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  options, cheap eats, and more affordable options around the neighborhood                      visitor-tips/affordable-times-square-guide           left                                          Affordable             Times Square             Affordable Times Square Guide             Happy
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  options, cheap eats, and more affordable options around the neighborhood                                                                   No Business           Like Show Business           What's on
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway           Check
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  out what
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  shows are playing right now                      shows           left                                          No Business             Like Show Business             What's on
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# Check out what
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  shows are playing right now                                                                   About           the Alliance           About the Alliance           Learn more about
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Times Square Alliance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and our work to improve and promote the district.                      about-the-alliance           left                                          About             the Alliance             About the Alliance             Learn more about
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Times Square Alliance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and our work to improve and promote the district.                                                                 COUNTDOWN TO NYE                                                                                                                Toggle navigatio

# %% [markdown]
# ## Most popular NER types

# %%
# Import the spaCy library
import spacy

# Load the downloaded English language model for spaCy
nlp = spacy.load("en_core_web_lg")

# Import Counter from collections module to count occurrences of each element
from collections import Counter

# Extract the labels of named entities from the processed text and count their occurrences
labels = [x.label_ for x in article.ents]
counter = Counter(labels)

# Print the count of each entity label
print(counter)
# Out:
# Counter({'NORP': 77, 'ORG': 7, 'FAC': 7, 'WORK_OF_ART': 6, 'LANGUAGE': 6, 'TIME': 4, 'DATE': 3, 'PRODUCT': 3, 'CARDINAL': 3, 'PERSON': 1})

# %% [markdown]
# ## Most Popular NER

# %%
# Extract the text of named entities from the processed text and count their occurrences
items = [x.text for x in article.ents]
counter_items = Counter(items)

# Get the five most common named entities and their counts
most_common_entities = counter_items.most_common(5)

# Print the result
print(most_common_entities)
# Out:
# [('Times Square', 2), ('just before', 2), ('Broadway', 2), ('the Times Square Alliance', 2), ('Afrikaans', 2)]

# %% [markdown]
#  ## Printing Sentences

# %%
# Import the spaCy library
import spacy

# Load the English language model for spaCy
nlp = spacy.load("en_core_web_lg")

# Extract sentences containing named entities from the processed text
sentences = [x for x in article.ents]

# Print the 21st sentence containing named entities
print(sentences[1:13])
# Out:
# [Midnight           Midnight Moment, Times Square, just before, Midnight             , Midnight Moment             , Each month, Times Square, just before, midnight, Affordable           Times Square           Affordable Times Square Guide           Happy hour, hour, Broadway           Check]

# %% [markdown]
#  ## NER Tags

# %%
# Import the displacy module from spaCy for entity visualization.
from spacy import displacy

# Render the 21st sentence containing named entities with entity visualization style
displacy.render(nlp(str(sentences[1:13])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midnight           Midnight Moment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , Times Square, just before,
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ,
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midnight Moment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Each month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , just before,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     midnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Affordable           Times Square           Affordable Times Square Guide           Happy hour, hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , Broadway           Check]</div></span>

# %% [markdown]
#  ## Types of Words in the Sentence

# %%
# Extract non-stopword and non-punctuation tokens from the 21st sentence containing named entities
tokens_info = [(x.orth_, x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences[1:13])) if not y.is_stop and y.pos_ != 'PUNCT']]

# Print the tokens' orthographic form, part-of-speech, and lemma
print(tokens_info)
# Out:
# [('Midnight', 'NOUN', 'midnight'), ('          ', 'SPACE', '          '), ('Midnight', 'PROPN', 'Midnight'), ('Moment', 'PROPN', 'Moment'), ('Times', 'PROPN', 'Times'), ('Square', 'PROPN', 'Square'), ('Midnight', 'PROPN', 'Midnight'), ('            ', 'SPACE', '            '), ('Midnight', 'PROPN', 'Midnight'), ('Moment', 'PROPN', 'Moment'), ('            ', 'SPACE', '            '), ('month', 'NOUN', 'month'), ('Times', 'PROPN', 'Times'), ('Square', 'PROPN', 'Square'), ('midnight', 'NOUN', 'midnight'), ('Affordable', 'PROPN', 'Affordable'), ('          ', 'SPACE', '          '), ('Times', 'PROPN', 'Times'), ('Square', 'PROPN', 'Square'), ('          ', 'SPACE', '          '), ('Affordable', 'PROPN', 'Affordable'), ('Times', 'PROPN', 'Times'), ('Square', 'PROPN', 'Square'), ('Guide', 'PROPN', 'Guide'), ('          ', 'SPACE', '          '), ('Happy', 'ADJ', 'happy'), ('hour', 'NOUN', 'hour'), ('hour', 'NOUN', 'hour'), ('Broadway', 'PROPN', 'Broadway'), ('          ', 'SPACE', '          '), ('Check', 'NOUN', 'check'), (']', 'X', ']')]

# %% [markdown]
#  ## Sentence Dependency

# %%
# Import the displacy module from spaCy for dependency visualization.
from spacy import displacy

# Render the dependency parse of the 21st sentence containing named entities and display it in Jupyter Notebook.
# Adjust the distance between tokens for better visualization.
displacy.render(nlp(str(sentences[1:3])), style='dep', jupyter=True, options={'distance': 200})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="05453825db76455583bea4f4779b9f62-0" class="displacy" width="1450" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Midnight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">          </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Midnight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Moment,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">Times</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Square]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-05453825db76455583bea4f4779b9f62-0-0" stroke-width="2px" d="M70,302.0 C70,2.0 850.0,2.0 850.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-05453825db76455583bea4f4779b9f62-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-05453825db76455583bea4f4779b9f62-0-1" stroke-width="2px" d="M270,302.0 C270,102.0 845.0,102.0 845.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-05453825db76455583bea4f4779b9f62-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,304.0 L262,292.0 278,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-05453825db76455583bea4f4779b9f62-0-2" stroke-width="2px" d="M270,302.0 C270,202.0 440.0,202.0 440.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-05453825db76455583bea4f4779b9f62-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M440.0,304.0 L448.0,292.0 432.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-05453825db76455583bea4f4779b9f62-0-3" stroke-width="2px" d="M670,302.0 C670,202.0 840.0,202.0 840.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-05453825db76455583bea4f4779b9f62-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,304.0 L662,292.0 678,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-05453825db76455583bea4f4779b9f62-0-4" stroke-width="2px" d="M1070,302.0 C1070,202.0 1240.0,202.0 1240.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-05453825db76455583bea4f4779b9f62-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1070,304.0 L1062,292.0 1078,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-05453825db76455583bea4f4779b9f62-0-5" stroke-width="2px" d="M870,302.0 C870,102.0 1245.0,102.0 1245.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-05453825db76455583bea4f4779b9f62-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1245.0,304.0 L1253.0,292.0 1237.0,292.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## importing SpaCy French language model

# %%
# run the next line only once if needed 
# This model includes word vectors and is useful for various natural language processing tasks.
# !python -m spacy download fr_core_news_sm

# Importing the spaCy library
import spacy

# Loading the downloaded English language model for spaCy
nlp = spacy.load("fr_core_news_sm")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#       --------------------------------------- 0.2/16.3 MB 14.1 MB/s eta 0:00:02
#      -- ------------------------------------- 0.9/16.3 MB 9.5 MB/s eta 0:00:02
#      -------- ------------------------------- 3.5/16.3 MB 24.6 MB/s eta 0:00:01
#      ---------- ----------------------------- 4.4/16.3 MB 21.6 MB/s eta 0:00:01
#      ---------------- ----------------------- 6.5/16.3 MB 26.1 MB/s eta 0:00:01
#      ---------------- ----------------------- 6.9/16.3 MB 21.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 9.7/16.3 MB 24.9 MB/s eta 0:00:01
#      ----------------------------- --------- 12.1/16.3 MB 31.1 MB/s eta 0:00:01
#      ----------------------------------- --- 15.0/16.3 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------  16.3/16.3 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  16.3/16.3 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------- 16.3/16.3 MB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from fr-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\shakkerar\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %% [markdown]
# ## example

# %%
import spacy
nlp = spacy.load("fr_core_news_sm")

text = "Frère Jacques Frère Jacques Dormez vous? Dormez vous? Sonnez les matines Sonnez les matines Ding ding dong Ding ding dong"
doc = nlp(text)

for sent in doc.sents:
    print(sent.text)
# Out:
# Frère Jacques Frère Jacques Dormez
# vous?
# Dormez vous?
# Sonnez les matines Sonnez les matines Ding ding dong Ding ding dong

# %% [markdown]
# ## Let’s Try on Real Dataset

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Change 'html5lib' to 'html.parser'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.france24.com/en/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 3

# %% [markdown]
# ## Have a Look At The NERS

# %%
# Visualize named entities in the article using displacy
from spacy import displacy
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Access
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  deniedYou don't have permission to access the page you requested.What is this page?The website you are visiting is protected.For security reasons this page cannot be displayed.France âª
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MÃ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ©dias âª
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %%
# Count the frequency of each named entity label in the article
from collections import Counter
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 2, 'MISC': 1})

# %% [markdown]
# ## Most Popular NER

# %%
# Extract the text of each named entity in the article and count the most common 5 entities
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('Access', 1), ('MÃ', 1), ('Monde', 1)]

# %% [markdown]
# ## Let’s Pick One Sentence to Analyze

# %%
# Extract sentences from the article and print the first sentence
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# Access deniedYou don't have permission to access the

# %% [markdown]
# ## NER Tags

# %%
# Visualize named entities in the first sentence of the article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Access
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  deniedYou don't have permission to access the</div></span>

# %% [markdown]
# ## Types of Words in Sentence

# %%
# Extract orthographic form, part-of-speech, and lemma of non-stopword, non-punctuation tokens in the first sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y
                                      for y
                                      in nlp(str(sentences[0]))
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Access', 'PROPN', 'Access'),
#  ('deniedYou', 'PROPN', 'deniedYou'),
#  ("don'", 'PROPN', "don'"),
#  ('t', 'NOUN', 't'),
#  ('have', 'ADJ', 'hav'),
#  ('permission', 'NOUN', 'permission'),
#  ('to', 'ADJ', 'to'),
#  ('access', 'VERB', 'access'),
#  ('the', 'X', 'the')]

# %% [markdown]
# ## Sentence Dependency Tree

# %%
# Visualize dependency parse of the first sentence of the article with custom distance between words
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True,
                options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="1b0c23b6c4124e628ba08001c11db5b0-0" class="displacy" width="1130" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Access</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">deniedYou</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">don'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">t</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">permission</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">access</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M155.0,244.0 L163.0,232.0 147.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-1" stroke-width="2px" d="M70,242.0 C70,122.0 280.0,122.0 280.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,244.0 L288.0,232.0 272.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-2" stroke-width="2px" d="M430,242.0 C430,122.0 640.0,122.0 640.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-3" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,244.0 L542,232.0 558,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-4" stroke-width="2px" d="M70,242.0 C70,62.0 645.0,62.0 645.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,244.0 L653.0,232.0 637.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-5" stroke-width="2px" d="M790,242.0 C790,182.0 875.0,182.0 875.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,244.0 L782,232.0 798,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1b0c23b6c4124e628ba08001c11db5b0-0-6" stroke-width="2px" d="M70,242.0 C70,2.0 890.0,2.0 890.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1b0c23b6c4124e628ba08001c11db5b0-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,244.0 L898.0,232.0 882.0,232.0" fill="currentColor"/>
# </g>
# </svg></span>
